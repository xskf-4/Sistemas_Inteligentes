# %%
# abstract class
class Problem:
    def __init__(self, initial, goal):
        self.initial = initial # Estado inicial
        self.goal = goal # Meta
    
    def actions(self, state):
        raise NotImplementedError

    # Función de transición
    def result(self, state, action):
        raise NotImplementedError

    # Función de desempeño
    def is_goal(self, state):
        return self.goal == state
    
    def action_cost(self, state1, action, state2):
        return 1

    def h(self, state):
        return 0

# %%
# graph problem
class GraphProblem(Problem):
    def __init__(self, initial, goal, graph):
        super().__init__(initial, goal)
        self.graph = graph
    
    def actions(self, state):
        lista = []
        for key in self.graph[state].keys():
            lista.append(key)
        return lista

    # Función de transición
    def result(self, state, action):
        return action

    def action_cost(self, state1, action, state2):
        return self.graph[state1][state2]

# %%
CDMX_subway = {
    # LÍNEA 1 (Color Rosa)
    "Observatorio": {"Tacubaya": 1},
    "Tacubaya": {"Observatorio": 1, "Juanacatlán": 1, "Patriotismo": 1, "Constituyentes": 1, "San Pedro de los Pinos": 1},
    "Juanacatlán": {"Tacubaya": 1, "Chapultepec": 1},
    "Chapultepec": {"Juanacatlán": 1, "Sevilla": 1},
    "Sevilla": {"Chapultepec": 1, "Insurgentes": 1},
    "Insurgentes": {"Sevilla": 1, "Cuauhtémoc": 1},
    "Cuauhtémoc": {"Insurgentes": 1, "Balderas": 1},
    "Balderas": {"Cuauhtémoc": 1, "Salto del Agua": 1, "Juárez": 1, "Niños Héroes": 1},
    "Salto del Agua": {"Balderas": 1, "Isabel la Católica": 1, "San Juan de Letrán": 1, "Doctores": 1},
    "Isabel la Católica": {"Salto del Agua": 1, "Pino Suárez": 1},
    "Pino Suárez": {"Isabel la Católica": 1, "Merced": 1, "Zócalo": 1, "San Antonio Abad": 1},
    "Merced": {"Pino Suárez": 1, "Candelaria": 1},
    "Candelaria": {"Merced": 1, "San Lázaro": 1, "Morelos": 1, "Fray Servando": 1},
    "San Lázaro": {"Candelaria": 1, "Moctezuma": 1, "Morelos": 1, "Flores Magón": 1},
    "Moctezuma": {"San Lázaro": 1, "Balbuena": 1},
    "Balbuena": {"Moctezuma": 1, "Boulevard Puerto Aéreo": 1},
    "Boulevard Puerto Aéreo": {"Balbuena": 1, "Gómez Farías": 1},
    "Gómez Farías": {"Boulevard Puerto Aéreo": 1, "Zaragoza": 1},
    "Zaragoza": {"Gómez Farías": 1, "Pantitlán": 1},
    "Pantitlán": {"Zaragoza": 1, "Hangares": 1, "Puebla": 1, "Agrícola Oriental": 1},

    # LÍNEA 2 (Color Azul)
    "Cuatro Caminos": {"Panteones": 1},
    "Panteones": {"Cuatro Caminos": 1, "Tacuba": 1},
    "Tacuba": {"Panteones": 1, "Cuitláhuac": 1, "Refinería": 1, "San Joaquín": 1},
    "Cuitláhuac": {"Tacuba": 1, "Popotla": 1},
    "Popotla": {"Cuitláhuac": 1, "Colegio Militar": 1},
    "Colegio Militar": {"Popotla": 1, "Normal": 1},
    "Normal": {"Colegio Militar": 1, "San Cosme": 1},
    "San Cosme": {"Normal": 1, "Revolución": 1},
    "Revolución": {"San Cosme": 1, "Hidalgo": 1},
    "Hidalgo": {"Revolución": 1, "Bellas Artes": 1, "Guerrero": 1, "Juárez": 1},
    "Bellas Artes": {"Hidalgo": 1, "Allende": 1, "Garibaldi": 1, "San Juan de Letrán": 1},
    "Allende": {"Bellas Artes": 1, "Zócalo": 1},
    "Zócalo": {"Allende": 1, "Pino Suárez": 1},
    "San Antonio Abad": {"Pino Suárez": 1, "Chabacano": 1},
    "Chabacano": {"San Antonio Abad": 1, "Viaducto": 1, "Obrera": 1, "La Viga": 1, "Lázaro Cárdenas": 1, "Jamaica": 1},
    "Viaducto": {"Chabacano": 1, "Xola": 1},
    "Xola": {"Viaducto": 1, "Villa de Cortés": 1},
    "Villa de Cortés": {"Xola": 1, "Nativitas": 1},
    "Nativitas": {"Villa de Cortés": 1, "Portales": 1},
    "Portales": {"Nativitas": 1, "Ermita": 1},
    "Ermita": {"Portales": 1, "General Anaya": 1, "Eje Central": 1, "Mexicaltzingo": 1},
    "General Anaya": {"Ermita": 1, "Tasqueña": 1},
    "Tasqueña": {"General Anaya": 1},

    # LÍNEA 3 (Color Verde)
    "Indios Verdes": {"Deportivo 18 de Marzo": 1},
    "Deportivo 18 de Marzo": {"Indios Verdes": 1, "Potrero": 1, "Lindavista": 1, "La Villa Basílica": 1},
    "Potrero": {"Deportivo 18 de Marzo": 1, "La Raza": 1},
    "La Raza": {"Potrero": 1, "Tlatelolco": 1, "Autobuses del Norte": 1, "Misterios": 1},
    "Tlatelolco": {"La Raza": 1, "Guerrero": 1},
    "Guerrero": {"Tlatelolco": 1, "Hidalgo": 1, "Buenavista": 1, "Garibaldi": 1},
    "Juárez": {"Hidalgo": 1, "Balderas": 1},
    "Niños Héroes": {"Balderas": 1, "Hospital General": 1},
    "Hospital General": {"Niños Héroes": 1, "Centro Médico": 1},
    "Centro Médico": {"Hospital General": 1, "Etiopía": 1, "Chilpancingo": 1, "Lázaro Cárdenas": 1},
    "Etiopía": {"Centro Médico": 1, "Eugenia": 1},
    "Eugenia": {"Etiopía": 1, "División del Norte": 1},
    "División del Norte": {"Eugenia": 1, "Zapata": 1},
    "Zapata": {"División del Norte": 1, "Coyoacán": 1, "Hospital 20 de Noviembre": 1, "Parque de los Venados": 1},
    "Coyoacán": {"Zapata": 1, "Viveros": 1},
    "Viveros": {"Coyoacán": 1, "Miguel Ángel de Quevedo": 1},
    "Miguel Ángel de Quevedo": {"Viveros": 1, "Copilco": 1},
    "Copilco": {"Miguel Ángel de Quevedo": 1, "Universidad": 1},
    "Universidad": {"Copilco": 1},

    # LÍNEA 4 (Color Cian)
    "Martín Carrera": {"Talismán": 1, "La Villa Basílica": 1},
    "Talismán": {"Martín Carrera": 1, "Bondojito": 1},
    "Bondojito": {"Talismán": 1, "Consulado": 1},
    "Consulado": {"Bondojito": 1, "Canal del Norte": 1, "Valle Gómez": 1, "Eduardo Molina": 1},
    "Canal del Norte": {"Consulado": 1, "Morelos": 1},
    "Morelos": {"Canal del Norte": 1, "Candelaria": 1, "Tepito": 1, "San Lázaro": 1},
    "Fray Servando": {"Candelaria": 1, "Jamaica": 1},
    "Jamaica": {"Fray Servando": 1, "Santa Anita": 1, "Chabacano": 1, "Mixiuhca": 1},
    "Santa Anita": {"Jamaica": 1, "La Viga": 1, "Coyuya": 1},

    # LÍNEA 5 (Color Amarillo)
    "Politécnico": {"Instituto del Petróleo": 1},
    "Instituto del Petróleo": {"Politécnico": 1, "Autobuses del Norte": 1, "Vallejo": 1, "Lindavista": 1},
    "Autobuses del Norte": {"Instituto del Petróleo": 1, "La Raza": 1},
    "Misterios": {"La Raza": 1, "Valle Gómez": 1},
    "Valle Gómez": {"Misterios": 1, "Consulado": 1},
    "Eduardo Molina": {"Consulado": 1, "Aragón": 1},
    "Aragón": {"Eduardo Molina": 1, "Oceanía": 1},
    "Oceanía": {"Aragón": 1, "Terminal Aérea": 1, "Romero Rubio": 1, "Deportivo Oceanía": 1},
    "Terminal Aérea": {"Oceanía": 1, "Hangares": 1},
    "Hangares": {"Terminal Aérea": 1, "Pantitlán": 1},

    # LÍNEA 6 (Color Rojo)
    "El Rosario": {"Tezozómoc": 1, "Aquiles Serdán": 1},
    "Tezozómoc": {"El Rosario": 1, "Azcapotzalco": 1},
    "Azcapotzalco": {"Tezozómoc": 1, "Ferrería": 1},
    "Ferrería": {"Azcapotzalco": 1, "Norte 45": 1},
    "Norte 45": {"Ferrería": 1, "Vallejo": 1},
    "Vallejo": {"Norte 45": 1, "Instituto del Petróleo": 1},
    "Lindavista": {"Instituto del Petróleo": 1, "Deportivo 18 de Marzo": 1},
    "La Villa Basílica": {"Deportivo 18 de Marzo": 1, "Martín Carrera": 1},

    # LÍNEA 7 (Color Naranja)
    "Aquiles Serdán": {"El Rosario": 1, "Camarones": 1},
    "Camarones": {"Aquiles Serdán": 1, "Refinería": 1},
    "Refinería": {"Camarones": 1, "Tacuba": 1},
    "San Joaquín": {"Tacuba": 1, "Polanco": 1},
    "Polanco": {"San Joaquín": 1, "Auditorio": 1},
    "Auditorio": {"Polanco": 1, "Constituyentes": 1},
    "Constituyentes": {"Auditorio": 1, "Tacubaya": 1},
    "San Pedro de los Pinos": {"Tacubaya": 1, "San Antonio": 1},
    "San Antonio": {"San Pedro de los Pinos": 1, "Mixcoac": 1},
    "Mixcoac": {"San Antonio": 1, "Barranca del Muerto": 1, "Insurgentes Sur": 1},
    "Barranca del Muerto": {"Mixcoac": 1},

    # LÍNEA 8 (Color Verde Oscuro)
    "Garibaldi": {"Guerrero": 1, "Bellas Artes": 1, "Lagunilla": 1},
    "San Juan de Letrán": {"Bellas Artes": 1, "Salto del Agua": 1},
    "Doctores": {"Salto del Agua": 1, "Obrera": 1},
    "Obrera": {"Doctores": 1, "Chabacano": 1},
    "La Viga": {"Chabacano": 1, "Santa Anita": 1},
    "Coyuya": {"Santa Anita": 1, "Iztacalco": 1},
    "Iztacalco": {"Coyuya": 1, "Apatlaco": 1},
    "Apatlaco": {"Iztacalco": 1, "Aculco": 1},
    "Aculco": {"Apatlaco": 1, "Escuadrón 201": 1},
    "Escuadrón 201": {"Aculco": 1, "Atlalilco": 1},
    "Atlalilco": {"Escuadrón 201": 1, "Iztapalapa": 1, "Mexicaltzingo": 1, "Culhuacán": 1},
    "Iztapalapa": {"Atlalilco": 1, "Cerro de la Estrella": 1},
    "Cerro de la Estrella": {"Iztapalapa": 1, "UAM-I": 1},
    "UAM-I": {"Cerro de la Estrella": 1, "Constitución de 1917": 1},
    "Constitución de 1917": {"UAM-I": 1},

    # LÍNEA 9 (Color Café)
    "Patriotismo": {"Tacubaya": 1, "Chilpancingo": 1},
    "Chilpancingo": {"Patriotismo": 1, "Centro Médico": 1},
    "Lázaro Cárdenas": {"Centro Médico": 1, "Chabacano": 1},
    "Mixiuhca": {"Jamaica": 1, "Velódromo": 1},
    "Velódromo": {"Mixiuhca": 1, "Ciudad Deportiva": 1},
    "Ciudad Deportiva": {"Velódromo": 1, "Puebla": 1},
    "Puebla": {"Ciudad Deportiva": 1, "Pantitlán": 1},

    # LÍNEA A (Color Morado)
    "Agrícola Oriental": {"Pantitlán": 1, "Canal de San Juan": 1},
    "Canal de San Juan": {"Agrícola Oriental": 1, "Tepalcates": 1},
    "Tepalcates": {"Canal de San Juan": 1, "Guelatao": 1},
    "Guelatao": {"Tepalcates": 1, "Peñón Viejo": 1},
    "Peñón Viejo": {"Guelatao": 1, "Acatitla": 1},
    "Acatitla": {"Peñón Viejo": 1, "Santa Marta": 1},
    "Santa Marta": {"Acatitla": 1, "Los Reyes": 1},
    "Los Reyes": {"Santa Marta": 1, "La Paz": 1},
    "La Paz": {"Los Reyes": 1},

    # LÍNEA B (Color Verde con Gris)
    "Buenavista": {"Guerrero": 1},
    "Lagunilla": {"Garibaldi": 1, "Tepito": 1},
    "Tepito": {"Lagunilla": 1, "Morelos": 1},
    "Flores Magón": {"San Lázaro": 1, "Romero Rubio": 1},
    "Romero Rubio": {"Flores Magón": 1, "Oceanía": 1},
    "Deportivo Oceanía": {"Oceanía": 1, "Bosque de Aragón": 1},
    "Bosque de Aragón": {"Deportivo Oceanía": 1, "Villa de Aragón": 1},
    "Villa de Aragón": {"Bosque de Aragón": 1, "Nezahualcóyotl": 1},
    "Nezahualcóyotl": {"Villa de Aragón": 1, "Impulsora": 1},
    "Impulsora": {"Nezahualcóyotl": 1, "Río de los Remedios": 1},
    "Río de los Remedios": {"Impulsora": 1, "Múzquiz": 1},
    "Múzquiz": {"Río de los Remedios": 1, "Ecatepec": 1},
    "Ecatepec": {"Múzquiz": 1, "Olímpica": 1},
    "Olímpica": {"Ecatepec": 1, "Plaza Aragón": 1},
    "Plaza Aragón": {"Olímpica": 1, "Ciudad Azteca": 1},
    "Ciudad Azteca": {"Plaza Aragón": 1},

    # LÍNEA 12 (Color Dorado)
    "Insurgentes Sur": {"Mixcoac": 1, "Hospital 20 de Noviembre": 1},
    "Hospital 20 de Noviembre": {"Insurgentes Sur": 1, "Zapata": 1},
    "Parque de los Venados": {"Zapata": 1, "Eje Central": 1},
    "Eje Central": {"Parque de los Venados": 1, "Ermita": 1},
    "Mexicaltzingo": {"Ermita": 1, "Atlalilco": 1},
    "Culhuacán": {"Atlalilco": 1, "San Andrés Tomatlán": 1},
    "San Andrés Tomatlán": {"Culhuacán": 1, "Lomas Estrella": 1},
    "Lomas Estrella": {"San Andrés Tomatlán": 1, "Calle 11": 1},
    "Calle 11": {"Lomas Estrella": 1, "Periférico Oriente": 1},
    "Periférico Oriente": {"Calle 11": 1, "Tezonco": 1},
    "Tezonco": {"Periférico Oriente": 1, "Olivos": 1},
    "Olivos": {"Tezonco": 1, "Nopalera": 1},
    "Nopalera": {"Olivos": 1, "Zapotitlán": 1},
    "Zapotitlán": {"Nopalera": 1, "Tlaltenco": 1},
    "Tlaltenco": {"Zapotitlán": 1, "Tláhuac": 1},
    "Tláhuac": {"Tlaltenco": 1}
}

# %%
class Node:
    def __init__(self, state, parent = None, action = None, path_cost = 0):
        self.state = state
        self.parent = parent
        self.action = action
        self.path_cost = path_cost

    def path(self):
        lista_path = []
        node = self
        while node:
            lista_path.append(node.state)
            node = node.parent
        return lista_path[::-1]

    def expand(self, problem):
        lista = []
        for action in problem.actions(self.state):
            lista.append(self.child_node(problem, action))
        return lista

    def child_node(self, problem, action):
        next_state = problem.result(self.state, action)
        step_cost = problem.action_cost(self.state, action, next_state)
        return Node(next_state, self, action, self.path_cost + step_cost)

# %%
def depth_first_graph_search(problem):
    start_node = Node(problem.initial)
    if problem.is_goal(start_node.state):
        return start_node
    frontier = [start_node]
    explored = set()

    while frontier:
        node = frontier.pop()
        explored.add(node.state)
        if problem.is_goal(node.state):
            return node

        for child in node.expand(problem):
            if child.state not in explored:
                frontier.append(child)

    return None

# %%
from collections import deque
def breadth_first_graph_search(problem):
    start_node = Node(problem.initial)
    if problem.is_goal(start_node.state):
        return start_node
    frontier = deque([start_node])
    explored = set()

    while frontier:
        node = frontier.popleft()
        explored.add(node.state)
        if problem.is_goal(node.state):
            return node

        for child in node.expand(problem):
            if child.state not in explored:
                frontier.append(child)

    return None

# %%
# Primer recorrido 'Cuatro Caminos' -> 'Pantitlán'
problem_1 = GraphProblem("Cuatro Caminos", "Pantitlán", CDMX_subway)

dfs_node = depth_first_graph_search(problem_1)
bfs_node = breadth_first_graph_search(problem_1)

print("DFS:\n",dfs_node.path(), sep = "")
print(f"Costo: {dfs_node.path_cost}")
print("\nBFS:\n",bfs_node.path(), sep = "")
print(f"Costo: {bfs_node.path_cost}")
# Out:
# DFS:
# ['Cuatro Caminos', 'Panteones', 'Tacuba', 'San Joaquín', 'Polanco', 'Auditorio', 'Constituyentes', 'Tacubaya', 'San Pedro de los Pinos', 'San Antonio', 'Mixcoac', 'Insurgentes Sur', 'Hospital 20 de Noviembre', 'Zapata', 'Parque de los Venados', 'Eje Central', 'Ermita', 'Mexicaltzingo', 'Atlalilco', 'Escuadrón 201', 'Aculco', 'Apatlaco', 'Iztacalco', 'Coyuya', 'Santa Anita', 'La Viga', 'Chabacano', 'Jamaica', 'Mixiuhca', 'Velódromo', 'Ciudad Deportiva', 'Puebla', 'Pantitlán']
# Costo: 32
#
# BFS:
# ['Cuatro Caminos', 'Panteones', 'Tacuba', 'San Joaquín', 'Polanco', 'Auditorio', 'Constituyentes', 'Tacubaya', 'Patriotismo', 'Chilpancingo', 'Centro Médico', 'Lázaro Cárdenas', 'Chabacano', 'Jamaica', 'Mixiuhca', 'Velódromo', 'Ciudad Deportiva', 'Puebla', 'Pantitlán']
# Costo: 18

# %%
# Segundo recorrido 'Politécnico' -> 'Tasqueña'
# No existe Taxqueña, regresa None en ese caso
problem_2 = GraphProblem("Politécnico", "Tasqueña", CDMX_subway)

dfs_node = depth_first_graph_search(problem_2)
bfs_node = breadth_first_graph_search(problem_2)

print("DFS:\n",dfs_node.path(), sep = "")
print(f"Costo: {dfs_node.path_cost}")
print("\nBFS:\n",bfs_node.path(), sep = "")
print(f"Costo: {bfs_node.path_cost}")
# Out:
# DFS:
# ['Politécnico', 'Instituto del Petróleo', 'Lindavista', 'Deportivo 18 de Marzo', 'La Villa Basílica', 'Martín Carrera', 'Talismán', 'Bondojito', 'Consulado', 'Eduardo Molina', 'Aragón', 'Oceanía', 'Romero Rubio', 'Flores Magón', 'San Lázaro', 'Morelos', 'Tepito', 'Lagunilla', 'Garibaldi', 'Bellas Artes', 'San Juan de Letrán', 'Salto del Agua', 'Doctores', 'Obrera', 'Chabacano', 'Jamaica', 'Santa Anita', 'Coyuya', 'Iztacalco', 'Apatlaco', 'Aculco', 'Escuadrón 201', 'Atlalilco', 'Mexicaltzingo', 'Ermita', 'General Anaya', 'Tasqueña']
# Costo: 36
#
# BFS:
# ['Politécnico', 'Instituto del Petróleo', 'Autobuses del Norte', 'La Raza', 'Tlatelolco', 'Guerrero', 'Hidalgo', 'Bellas Artes', 'Allende', 'Zócalo', 'Pino Suárez', 'San Antonio Abad', 'Chabacano', 'Viaducto', 'Xola', 'Villa de Cortés', 'Nativitas', 'Portales', 'Ermita', 'General Anaya', 'Tasqueña']
# Costo: 20

# %%
# Tercer recorrido 'Zapata' -> 'Oceanía'
# No existe Oceania, regresa None en ese caso
problem_3 = GraphProblem("Zapata", "Oceanía", CDMX_subway)

dfs_node = depth_first_graph_search(problem_3)
bfs_node = breadth_first_graph_search(problem_3)

print("DFS:\n",dfs_node.path(), sep = "")
print(f"Costo: {dfs_node.path_cost}")
print("\nBFS:\n",bfs_node.path(), sep = "")
print(f"Costo: {bfs_node.path_cost}")
# Out:
# DFS:
# ['Zapata', 'Parque de los Venados', 'Eje Central', 'Ermita', 'Mexicaltzingo', 'Atlalilco', 'Escuadrón 201', 'Aculco', 'Apatlaco', 'Iztacalco', 'Coyuya', 'Santa Anita', 'La Viga', 'Chabacano', 'Jamaica', 'Mixiuhca', 'Velódromo', 'Ciudad Deportiva', 'Puebla', 'Pantitlán', 'Hangares', 'Terminal Aérea', 'Oceanía']
# Costo: 22
#
# BFS:
# ['Zapata', 'División del Norte', 'Eugenia', 'Etiopía', 'Centro Médico', 'Lázaro Cárdenas', 'Chabacano', 'Jamaica', 'Fray Servando', 'Candelaria', 'San Lázaro', 'Flores Magón', 'Romero Rubio', 'Oceanía']
# Costo: 13
